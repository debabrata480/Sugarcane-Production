# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("List of Countries by Sugarcane Production.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df.shape
# Out:
# (103, 7)

# %% [markdown]
# #Data cleaning

# %%
df["Production (Tons)"]=df["Production (Tons)"].str.replace(".",",")
df["Production per Person (Kg)"]=df["Production per Person (Kg)"].str.replace(".",",")
df["Acreage (Hectare)"]=df["Acreage (Hectare)"].str.replace(".",",")
df["Yield (Kg / Hectare)"]=df["Yield (Kg / Hectare)"].str.replace(".",",")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768,678,382
# 1           1     India           Asia       348,448,000
# 2           2     China           Asia       123,059,739
# 3           3  Thailand           Asia        87,468,496
# 4           4  Pakistan           Asia        65,450,704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3,668,531        10,226,205             75,167,5
# 1                     260721         4,950,000             70,393,5
# 2                      88287         1,675,215             73,459,1
# 3                  1,264,303         1,336,575             65,442,2
# 4                     324219         1,130,820               57,879

# %%
df.rename(columns={"Production (Tons)":"Production (Tons)"},inplace=True)
df.rename(columns={"Production per Person (Kg)":"Production per Person (Kg)"},inplace=True)
df.rename(columns={"Acreage (Hectare)":"Acreage (Hectare)"},inplace=True)
df.rename(columns={"Yield (Kg / Hectare)":"Yield (Kg / Hectare)"},inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768,678,382
# 1           1     India           Asia       348,448,000
# 2           2     China           Asia       123,059,739
# 3           3  Thailand           Asia        87,468,496
# 4           4  Pakistan           Asia        65,450,704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3,668,531        10,226,205             75,167,5
# 1                     260721         4,950,000             70,393,5
# 2                      88287         1,675,215             73,459,1
# 3                  1,264,303         1,336,575             65,442,2
# 4                     324219         1,130,820               57,879

# %%
df.isna().sum()
# Out:
# Unnamed: 0                    0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             1
# Yield (Kg / Hectare)          1
# dtype: int64

# %%
df[df["Acreage (Hectare)"].isnull()]
# Out:
#     Unnamed: 0   Country Continent Production (Tons)  \
# 99          99  Djibouti    Africa                53
#
#    Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 99                         51               NaN                  NaN

# %%
df=df.dropna().reset_index()

# %%
df.head()
# Out:
#    index  Unnamed: 0   Country      Continent Production (Tons)  \
# 0      0           0    Brazil  South America       768,678,382
# 1      1           1     India           Asia       348,448,000
# 2      2           2     China           Asia       123,059,739
# 3      3           3  Thailand           Asia        87,468,496
# 4      4           4  Pakistan           Asia        65,450,704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3,668,531        10,226,205             75,167,5
# 1                     260721         4,950,000             70,393,5
# 2                      88287         1,675,215             73,459,1
# 3                  1,264,303         1,336,575             65,442,2
# 4                     324219         1,130,820               57,879

# %%
df.drop(["index","Unnamed: 0"],axis=1,inplace=True)

# %%
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America       768,678,382                  3,668,531
# 1     India           Asia       348,448,000                     260721
# 2     China           Asia       123,059,739                      88287
# 3  Thailand           Asia        87,468,496                  1,264,303
# 4  Pakistan           Asia        65,450,704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0        10,226,205             75,167,5
# 1         4,950,000             70,393,5
# 2         1,675,215             73,459,1
# 3         1,336,575             65,442,2
# 4         1,130,820               57,879

# %%
df.dtypes
# Out:
# Country                       object
# Continent                     object
# Production (Tons)             object
# Production per Person (Kg)    object
# Acreage (Hectare)             object
# Yield (Kg / Hectare)          object
# dtype: object

# %%
df["Production (Tons)"]=df["Production (Tons)"].str.replace(",","").astype(float)
df["Production per Person (Kg)"]=df["Production per Person (Kg)"].str.replace(",","").astype(float)
df["Acreage (Hectare)"]=df["Acreage (Hectare)"].str.replace(",","").astype(float)
df["Yield (Kg / Hectare)"]=df["Yield (Kg / Hectare)"].str.replace(",","").astype(float)

# %%
df.head()
# Out:
#     Country      Continent  Production (Tons)  Production per Person (Kg)  \
# 0    Brazil  South America        768678382.0                   3668531.0
# 1     India           Asia        348448000.0                    260721.0
# 2     China           Asia        123059739.0                     88287.0
# 3  Thailand           Asia         87468496.0                   1264303.0
# 4  Pakistan           Asia         65450704.0                    324219.0
#
#    Acreage (Hectare)  Yield (Kg / Hectare)
# 0         10226205.0              751675.0
# 1          4950000.0              703935.0
# 2          1675215.0              734591.0
# 3          1336575.0              654422.0
# 4          1130820.0               57879.0

# %%
df.nunique()
# Out:
# Country                       102
# Continent                       6
# Production (Tons)             102
# Production per Person (Kg)    101
# Acreage (Hectare)             101
# Yield (Kg / Hectare)          102
# dtype: int64

# %% [markdown]
# How many countries produce sugarcane from each continent?

# %%
df["Continent"].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df["Continent"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Continent'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 10))

# Subplot 1
plt.subplot(2, 2, 1)
sns.histplot(df["Production (Tons)"], kde=True)
plt.title("Production (Tons)")

# Subplot 2
plt.subplot(2, 2, 2)
sns.histplot(df["Production per Person (Kg)"], kde=True)  # Fixed closing bracket
plt.title("Production per Person (Kg)")

# Subplot 3
plt.subplot(2, 2, 3)
sns.histplot(df["Acreage (Hectare)"], kde=True)
plt.title("Acreage (Hectare)")

# Subplot 4
plt.subplot(2, 2, 4)
sns.histplot(df["Yield (Kg / Hectare)"], kde=True)
plt.title("Yield (Kg / Hectare)")

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %%
from collections import defaultdict
k=list(df["Continent"])
l=list(df["Country"])
# Creating a defaultdict with lists as default values
my_dict = defaultdict(list)
t=0
for i in range(len(k)):
    my_dict[k[i]].append(l[i])
print(my_dict["South America"])
# Out:
# ['Brazil', 'Colombia', 'Argentina', 'Peru', 'Ecuador', 'Bolivia', 'Paraguay', 'Venezuela', 'Guyana', 'Uruguay', 'Suriname']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 10))

# Subplot 1 - Production (Tons)
plt.subplot(2, 2, 1)
sns.boxplot(x=df["Production (Tons)"])
plt.title("Production (Tons)")

# Subplot 2 - Production per Person (Kg)
plt.subplot(2, 2, 2)
sns.boxplot(x=df["Production per Person (Kg)"])
plt.title("Production per Person (Kg)")

# Subplot 3 - Acreage (Hectare)
plt.subplot(2, 2, 3)
sns.boxplot(x=df["Acreage (Hectare)"])
plt.title("Acreage (Hectare)")

# Subplot 4 - Yield (Kg / Hectare)
plt.subplot(2, 2, 4)
sns.boxplot(x=df["Yield (Kg / Hectare)"])
plt.title("Yield (Kg / Hectare)")

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %%
df.describe()
# Out:
#        Production (Tons)  Production per Person (Kg)  Acreage (Hectare)  \
# count       1.020000e+02                1.020000e+02       1.020000e+02
# mean        1.850372e+07                4.124805e+05       2.498981e+05
# std         8.419149e+07                8.669140e+05       1.137003e+06
# min         1.000000e+00                0.000000e+00       0.000000e+00
# 25%         6.251875e+04                1.075225e+04       1.104000e+03
# 50%         1.440044e+06                8.135850e+04       1.655800e+04
# 75%         6.426824e+06                2.828128e+05       8.047400e+04
# max         7.686784e+08                4.816299e+06       1.022620e+07
#
#        Yield (Kg / Hectare)
# count          1.020000e+02
# mean           5.018502e+05
# std            3.169530e+05
# min            1.000000e+01
# 25%            2.487505e+05
# 50%            5.102500e+05
# 75%            7.198920e+05
# max            1.290493e+06

# %%
my_new={}
t=0
for i in range(len(k)):
    try:
        my_new[k[i]]=my_new[k[i]]+1
    except:
        my_new[k[i]]=1

# %%
print(my_new)
# Out:
# {'South America': 11, 'Asia': 25, 'North America': 22, 'Oceania': 4, 'Africa': 38, 'Europe': 2}

# %%
g=df.groupby("Continent")
print(g)
for continent, group in g:
    print(f"Group: {continent}")
    print(group)
    print("-" * 50)  # Separator for better readability
# Out:
# ...
# Group: Africa
#                      Country Continent  Production (Tons)  \
# 15                     Egypt    Africa         15760418.0
# 16              South Africa    Africa         15074610.0
# 22                     Kenya    Africa          7094619.0
# 26                 Swaziland    Africa          5583295.0
# 27                     Sudan    Africa          5525059.0
# 31                    Zambia    Africa          4285839.0
# 34                 Mauritius    Africa          3798448.0
# 35                    Uganda    Africa          3723019.0
# 36                  Zimbabwe    Africa          3483000.0
# 38                Madagascar    Africa          3005641.0
# 39                  Tanzania    Africa          2994127.0
# 40                    Malawi    Africa          2915406.0
# 41                Mozambique    Africa          2761505.0
# 44            Congo-Kinshasa    Africa          2191333.0
# 46             Côte d'Ivoire    Africa          1982661.0
# ...

# %%
#which country produces maximum sugarcane ?
df_new=df[["Country","Production (Tons)"]].set_index("Country")

# %%
df_new
# Out:
#            Production (Tons)
# Country
# Brazil           768678382.0
# India            348448000.0
# China            123059739.0
# Thailand          87468496.0
# Pakistan          65450704.0
# ...                      ...
# Spain                  394.0
# Lebanon                 97.0
# Singapore               50.0
# Samoa                   12.0
# Syria                    1.0
#
# [102 rows x 1 columns]

# %%
df_new["Production(Tons)_percent"]=df_new["Production (Tons)"]*100/df_new["Production (Tons)"].sum()

# %%
df_new
# Out:
#            Production (Tons)  Production(Tons)_percent
# Country
# Brazil           768678382.0              4.072729e+01
# India            348448000.0              1.846200e+01
# China            123059739.0              6.520138e+00
# Thailand          87468496.0              4.634389e+00
# Pakistan          65450704.0              3.467809e+00
# ...                      ...                       ...
# Spain                  394.0              2.087551e-05
# Lebanon                 97.0              5.139401e-06
# Singapore               50.0              2.649176e-06
# Samoa                   12.0              6.358022e-07
# Syria                    1.0              5.298352e-08
#
# [102 rows x 2 columns]

# %%
df_new["Production(Tons)_percent"].max()
# Out:
# 40.72728543291318

# %%
df_new["Production(Tons)_percent"].plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='Production(Tons)_percent'>

# %%
df_new["Production(Tons)_percent"].head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
ax=sns.barplot(data=df.head(10),x="Country",y="Production (Tons)")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_66984\3836565765.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %%
#which country has the highest land
df_acr=df.sort_values("Acreage (Hectare)",ascending=False)
ax=sns.barplot(data=df_acr.head(10),x="Country",y="Acreage (Hectare)")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_66984\1277933029.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %%
#which country has highest yield per hectare?
df_yield=df.sort_values("Yield (Kg / Hectare)",ascending=False)
ax=sns.barplot(data=df_yield.head(10),x="Country",y="Yield (Kg / Hectare)")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_66984\1481570580.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %%
#Correlatio
df_corr = df.corr(numeric_only=True)
print(df_corr)
# Out:
#                             Production (Tons)  Production per Person (Kg)  \
# Production (Tons)                    1.000000                    0.352369
# Production per Person (Kg)           0.352369                    1.000000
# Acreage (Hectare)                    0.997550                    0.341974
# Yield (Kg / Hectare)                 0.121125                    0.226719
#
#                             Acreage (Hectare)  Yield (Kg / Hectare)
# Production (Tons)                    0.997550              0.121125
# Production per Person (Kg)           0.341974              0.226719
# Acreage (Hectare)                    1.000000              0.107826
# Yield (Kg / Hectare)                 0.107826              1.000000

# %%
#do countries with highest land produce more sugarcane
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap="Greens")
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df,x="Acreage (Hectare)",y="Production (Tons)")
# Out:
# <Axes: xlabel='Acreage (Hectare)', ylabel='Production (Tons)'>

# %%
#Do countries which yield more sugarcane per hectare produces more sugarcane in total?
sns.scatterplot(data=df,x="Yield (Kg / Hectare)",y="Production (Tons)")
# Out:
# <Axes: xlabel='Yield (Kg / Hectare)', ylabel='Production (Tons)'>

# %%
#analysis of continent

# %%
df_continent=df.groupby("Continent").sum().drop("Country",axis=1)

# %%
df_continent
# Out:
#                Production (Tons)  Production per Person (Kg)  \
# Continent
# Africa                89681472.0                  10144110.0
# Asia                 721930425.0                   3120808.0
# Europe                    5823.0                       536.0
# North America        173995947.0                  15420953.0
# Oceania               36177574.0                   3158066.0
# South America        865588126.0                  10228540.0
#
#                Acreage (Hectare)  Yield (Kg / Hectare)
# Continent
# Africa                 1439089.0            20700454.0
# Asia                  10608319.0            11197308.0
# Europe                      71.0             1318709.0
# North America          1581983.0             9581162.0
# Oceania                 490909.0             1624191.0
# South America         11369236.0             6766896.0

# %%
#which continent produces maximum sugarcane
df_continent["Production (Tons)"].sort_values(ascending=False)
# Out:
# Continent
# South America    865588126.0
# Asia             721930425.0
# North America    173995947.0
# Africa            89681472.0
# Oceania           36177574.0
# Europe                5823.0
# Name: Production (Tons), dtype: float64

# %%
df_continent["Production (Tons)"].sort_values(ascending=False).plot(kind="bar")
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# Do number of countries in a continent affects production of sugarcane?

# %%
df_continent["number_of_countries"] = df.groupby("Continent").count()["Country"]

# %%
df_continent
# Out:
#                Production (Tons)  Production per Person (Kg)  \
# Continent
# Africa                89681472.0                  10144110.0
# Asia                 721930425.0                   3120808.0
# Europe                    5823.0                       536.0
# North America        173995947.0                  15420953.0
# Oceania               36177574.0                   3158066.0
# South America        865588126.0                  10228540.0
#
#                Acreage (Hectare)  Yield (Kg / Hectare)  number_of_countries
# Continent
# Africa                 1439089.0            20700454.0                   38
# Asia                  10608319.0            11197308.0                   25
# Europe                      71.0             1318709.0                    2
# North America          1581983.0             9581162.0                   22
# Oceania                 490909.0             1624191.0                    4
# ...

# %%
continents_names=df_continent.index.to_list()
print(continents_names)
# Out:
# ['Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America']

# %%
sns.lineplot(data=df_continent,x="number_of_countries",y="Production (Tons)")
plt.xticks(df_continent["number_of_countries"],continents_names,rotation=90)
plt.show()

# %%
#do continent with highest land produces more sugarcane?

# %%
#producton distribuiton by continent
df_continent["Production (Tons)"].plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='Production (Tons)'>
